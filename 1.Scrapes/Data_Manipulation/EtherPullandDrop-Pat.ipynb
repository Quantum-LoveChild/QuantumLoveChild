# %%
import pandas as pd
import time
import conn_creds as cc
import numpy as np
import requests, datetime, re
from bs4 import BeautifulSoup
import mysql.connector
from sqlalchemy import create_engine
import sqlalchemy
pd.options.mode.chained_assignment = None

# establish MySQL engine with credentials
db_name = 'crypto_price_db'
engine = create_engine('mysql+mysqlconnector://'+cc.db_username+':'+cc.db_pass+'@'+cc.db_host+':'+cc.db_port+'/'+db_name, echo=False)

# %%
## Function for cleaning up df before MySQL push

def cmc_df_cleanup(df):
    # convert all random characters in string varaibles into nan
    df = df[['coin_name','date_hist','open_price','close_price','high_price','low_price','market_cap','volume']]
    df[['open_price','close_price','high_price','low_price','market_cap','volume']] = (
    df[['open_price','close_price','high_price','low_price','market_cap','volume']].apply(lambda x: x.str.replace(',','')))
    df[['open_price','close_price','high_price','low_price','market_cap','volume']] = (
    df[['open_price','close_price','high_price','low_price','market_cap','volume']].apply(lambda x: x.replace('-|^\s*$',np.nan,regex=True)))
    #convert to datetime
    df['date_hist'] = pd.to_datetime(df['date_hist'])
    return df

## Function for updating missing historical data in CMC

def pull_cmc(coin,start_date):
    try:
        final_coin_data = pd.DataFrame()
        url = 'https://coinmarketcap.com/currencies/' + coin + '/historical-data/?start=' + start_date.replace('-','') + "&end=" + str(datetime.datetime.now())[:10].replace('-','')

        r = requests.get(url)

        soup = BeautifulSoup(r.text, 'lxml')
        table = soup.find('table')

        headers = {'coin_name': [np.nan], 'date_hist': [np.nan], 'open_price': [np.nan], 'high_price': [np.nan], 'low_price': [np.nan], 'close_price': [np.nan], 'volume': [np.nan], 'market_cap': [np.nan]}
        coin_data = pd.DataFrame(headers)

        for row in table.find_all('tr')[1:]:
            col = row.find_all('td')

            coin_name = coin
            date = col[0].text.strip()
            open_price = col[1].text.strip()
            high_price = col[2].text.strip()
            low_price = col[3].text.strip()
            close_price = col[4].text.strip()
            volume = col[5].text.strip()
            market_cap = col[6].text.strip()

            temp_df = {'coin_name':coin_name,'date_hist': date, 'open_price': open_price, 'high_price': high_price, 'low_price': low_price, 'close_price': close_price, 'volume': volume, 'market_cap': market_cap}
            coin_data = coin_data.append(temp_df, ignore_index=True)

        coin_data = coin_data.drop(0)
        final_coin_data = final_coin_data.append(coin_data)
        print(str(count) + '. ' + str(coin) + '...done')
        return final_coin_data
    except:
        print(str(count)+ '. missing '+ str(coin))

# %%
### Initial pull: use this to build a database in MySQL to pull all CoinMarketCap (CMC) data.
## Step 1 of 2: Build pandas dataframe of historical coin data.

#build list of each coin
url = 'https://coinmarketcap.com/all/views/all/'
r = requests.get(url)
soup = BeautifulSoup(r.content, 'html5lib')
names=soup.find_all("a",{"class":"currency-name-container"})
names_strings = [str(i) for i in names]

## pull name from each string in a list
names_list =[]
for x in names_strings:
    names_list.append(re.split('/"|currencies/',x)[-2])

#scrape each coin
final_coin_data = pd.DataFrame()
count = 0
missing_coins = []

for item in names_list:
    count += 1
    try:
        url = 'https://coinmarketcap.com/currencies/' + item + '/historical-data/?start=20100101&end=' + str(datetime.datetime.now())[:10].replace('-','')
        r = requests.get(url)

        soup = BeautifulSoup(r.text, 'lxml')
        table = soup.find('table')

        headers = {'coin_name': [np.nan], 'date_hist': [np.nan], 'open_price': [np.nan], 'high_price': [np.nan], 'low_price': [np.nan], 'close_price': [np.nan], 'volume': [np.nan], 'market_cap': [np.nan]}
        coin_data = pd.DataFrame(headers)

        for row in table.find_all('tr')[1:]:
            col = row.find_all('td')

            coin_name = item
            date = col[0].text.strip()
            open_price = col[1].text.strip()
            high_price = col[2].text.strip()
            low_price = col[3].text.strip()
            close_price = col[4].text.strip()
            volume = col[5].text.strip()
            market_cap = col[6].text.strip()

            temp_df = {'coin_name':coin_name,'date_hist': date, 'open_price': open_price, 'high_price': high_price, 'low_price': low_price, 'close_price': close_price, 'volume': volume, 'market_cap': market_cap}
            coin_data = coin_data.append(temp_df, ignore_index=True)

        coin_data = coin_data.drop(0)
        final_coin_data = final_coin_data.append(coin_data)
        print(str(count) + '. ' + str(item) + '...done')
    except:
        missing_coins.append(item)
        print(str(count)+ '. missing '+ str(item))
        
final_coin_data = cmc_df_cleanup(final_coin_data)
final_coin_data.reset_index(drop=True,inplace=True)
# Out:
# 1. bitcoin...done
# 2. ethereum...done
# 3. ripple...done
# 4. bitcoin-cash...done
# 5. eos...done
# 6. cardano...done
# 7. litecoin...done
# 8. stellar...done
# 9. tron...done
# 10. iota...done
# 11. neo...done
# 12. monero...done
# 13. dash...done
# 14. nem...done
# 15. vechain...done
# 16. tether...done
# 17. ethereum-classic...done
# 18. qtum...done
# 19. omisego...done
# 20. icon...done
# 21. binance-coin...done
# 22. lisk...done
# 23. verge...done
# 24. bitcoin-gold...done
# 25. zcash...done
# 26. aeternity...done
# 27. nano...done
# 28. steem...done
# 29. bytom...done
# 30. ontology...done
# 31. bitshares...done
# 32. bytecoin-bcn...done
# 33. siacoin...done
# 34. populous...done
# 35. wanchain...done
# 36. bitcoin-diamond...done
# 37. bitcoin-private...done
# 38. zilliqa...done
# 39. stratis...done
# 40. waves...done
# 41. maker...done
# 42. rchain...done
# 43. 0x...done
# 44. dogecoin...done
# 45. decred...done
# 46. status...done
# 47. digixdao...done
# 48. mixin...done
# 49. loopring...done
# 50. basic-attention-token...done
# 51. aelf...done
# 52. aion...done
# 53. iostoken...done
# 54. hshare...done
# 55. golem-network-tokens...done
# 56. waltonchain...done
# 57. digibyte...done
# 58. augur...done
# 59. komodo...done
# 60. ardor...done
# 61. ark...done
# 62. nebulas-token...done
# 63. kyber-network...done
# 64. mithril...done
# 65. pivx...done
# 66. substratum...done
# 67. cortex...done
# 68. kucoin-shares...done
# 69. monacoin...done
# 70. qash...done
# 71. gas...done
# 72. centrality...done
# 73. syscoin...done
# 74. cryptonex...done
# 75. reddcoin...done
# 76. ethos...done
# 77. storm...done
# 78. waykichain...done
# 79. dragonchain...done
# 80. dentacoin...done
# 81. factom...done
# 82. nxt...done
# 83. pundi-x...done
# 84. elastos...done
# 85. gxchain...done
# 86. bancor...done
# 87. salt...done
# 88. gifto...done
# 89. funfair...done
# 90. wax...done
# 91. veritaseum...done
# 92. fusion...done
# 93. power-ledger...done
# 94. enigma-project...done
# 95. neblio...done
# 96. zcoin...done
# 97. nucleus-vision...done
# 98. chainlink...done
# 99. decentraland...done
# 100. kin...done
# 101. request-network...done
# 102. loom-network...done
# 103. monaco...done
# 104. maidsafecoin...done
# 105. cybermiles...done
# 106. tenx...done
# 107. achain...done
# 108. electroneum...done
# 109. revain...done
# 110. time-new-bank...done
# 111. byteball...done
# 112. deepbrain-chain...done
# 113. cindicator...done
# 114. storj...done
# 115. bottos...done
# 116. iconomi...done
# 117. nuls...done
# 118. smartcash...done
# 119. particl...done
# 120. civic...done
# 121. skycoin...done
# 122. sirin-labs-token...done
# 123. emercoin...done
# 124. zencash...done
# 125. poa-network...done
# 126. smartmesh...done
# 127. polymath-network...done
# 128. poet...done
# 129. nexus...done
# 130. huobi-token...done
# 131. matrix-ai-network...done
# 132. bitcoindark...done
# 133. boscoin...done
# 134. quantstamp...done
# 135. ruff...done
# 136. genaro-network...done
# 137. paypex...done
# 138. rlc...done
# 139. paypie...done
# 140. gnosis-gno...done
# 141. game...done
# 142. tokenpay...done
# 143. apex...done
# 144. metal...done
# 145. enjin-coin...done
# 146. arcblock...done
# 147. ignis...done
# 148. vertcoin...done
# 149. gamecredits...done
# 150. aragon...done
# 151. singularitynet...done
# 152. dynamic-trading-rights...done
# 153. litecoin-cash...done
# 154. santiment...done
# 155. raiden-network-token...done
# 156. bluzelle...done
# 157. bitcore...done
# 158. red-pulse...done
# 159. amber...done
# 160. dropil...done
# 161. dent...done
# 162. scryinfo...done
# 163. high-performance-blockchain...done
# 164. ethlend...done
# 165. dew...done
# 166. data...done
# 167. groestlcoin...done
# 168. blocknet...done
# 169. tomochain...done
# 170. digitalnote...done
# 171. sophiatx...done
# 172. sonm...done
# 173. medibloc...done
# 174. ubiq...done
# 175. all-sports...done
# 176. bridgecoin...done
# 177. zclassic...done
# 178. asch...done
# 179. nav-coin...done
# 180. thekey...done
# 181. primecoin...done
# 182. credits...done
# 183. theta-token...done
# 184. cube...done
# 185. pillar...done
# 186. genesis-vision...done
# 187. ost...done
# 188. blockv...done
# 189. airswap...done
# 190. iht-real-estate-protocol...done
# 191. eidoo...done
# 192. adx-net...done
# 193. cloakcoin...done
# 194. bibox-token...done
# 195. ink...done
# 196. nanjcoin...done
# 197. bread...done
# 198. ripio-credit-network...done
# 199. iot-chain...done
# 200. c20...done
# 201. bitbay...done
# 202. singulardtv...done
# 203. appcoins...done
# 204. einsteinium...done
# 205. quantum-resistant-ledger...done
# 206. streamr-datacoin...done
# 207. peercoin...done
# 208. district0x...done
# 209. vibe...done
# 210. wabi...done
# 211. delphy...done
# 212. wepower...done
# 213. ion...done
# 214. utrust...done
# 215. burst...done
# 216. telcoin...done
# 217. tokencard...done
# 218. salus...done
# 219. tierion...done
# 220. crypterium...done
# 221. wings...done
# 222. ins-ecosystem...done
# 223. hydro-protocol...done
# 224. viacoin...done
# 225. edgeless...done
# 226. modum...done
# 227. counterparty...done
# 228. bitrent...done
# 229. jibrel-network...done
# 230. library-credit...done
# 231. qlink...done
# 232. spankchain...done
# 233. odyssey...done
# 234. minexcoin...done
# 235. triggers...done
# 236. origintrail...done
# 237. electrifyasia...done
# 238. safe-exchange-coin...done
# 239. medishares...done
# 240. internet-node-token...done
# 241. banca...done
# 242. oyster...done
# 243. yoyow...done
# 244. etherparty...done
# 245. pura...done
# 246. wagerr...done
# 247. feathercoin...done
# 248. blox...done
# 249. blockmason...done
# 250. datx...done
# 251. electra...done
# 252. envion...done
# 253. melon...done
# 254. babb...done
# 255. kickico...done
# 256. rock...done
# 257. experience-points...done
# 258. datum...done
# 259. taas...done
# 260. steem-dollars...done
# 261. trinity-network-credit...done
# 262. bitcny...done
# 263. gulden...done
# 264. qunqun...done
# 265. universa...done
# 266. soarcoin...done
# 267. decent...done
# 268. mobius...done
# 269. metaverse...done
# 270. presearch...done
# 271. naga...done
# 272. true-chain...done
# 273. mobilego...done
# 274. cybervein...done
# 275. educare...done
# 276. shift...done
# 277. adtoken...done
# 278. viberate...done
# 279. republic-protocol...done
# 280. spectre-dividend...done
# 281. medical-chain...done
# 282. tokenomy...done
# 283. casinocoin...done
# 284. unikoin-gold...done
# 285. coss...done
# 286. yee...done
# 287. linkeye...done
# 288. zeepin...done
# 289. odem...done
# 290. sentinel...done
# 291. ravencoin...done
# 292. sentinel-chain...done
# 293. elastic...done
# 294. cpchain...done
# 295. trade-token...done
# 296. guppy...done
# 297. legolas-exchange...done
# 298. swftcoin...done
# 299. tokenclub...done
# 300. zoin...done
# 301. lunyr...done
# 302. cobinhood...done
# 303. phore...done
# 304. dimecoin...done
# 305. xtrabytes...done
# 306. xinfin-network...done
# 307. missing stk
# 308. cofound-it...done
# 309. humaniq...done
# 310. havven...done
# 311. dai...done
# 312. synereo...done
# 313. monetha...done
# 314. mercury...done
# 315. everex...done
# 316. lympo...done
# 317. namecoin...done
# 318. uptoken...done
# 319. bankex...done
# 320. potcoin...done
# 321. aeon...done
# 322. fortuna...done
# 323. crown...done
# 324. ugchain...done
# 325. echolink...done
# 326. aidoc...done
# 327. agrello-delta...done
# 328. refereum...done
# 329. deeponion...done
# 330. alphacat...done
# 331. aeron...done
# 332. lamden...done
# 333. cappasity...done
# 334. eccoin...done
# 335. pepe-cash...done
# 336. dmarket...done
# 337. mothership...done
# 338. firstblood...done
# 339. propy...done
# 340. unobtanium...done
# 341. iocoin...done
# 342. shield-xsh...done
# 343. peerplays-ppy...done
# 344. dimcoin...done
# 345. switcheo...done
# 346. bodhi...done
# 347. suncontract...done
# 348. shipchain...done
# 349. energo...done
# 350. hempcoin...done
# 351. html-coin...done
# 352. dock...done
# 353. blocktix...done
# 354. bean-cash...done
# 355. decision-token...done
# 356. stakenet...done
# 357. trust...done
# 358. zeusshield...done
# 359. u-network...done
# 360. olympus-labs...done
# 361. rentberry...done
# 362. karma...done
# 363. blackcoin...done
# 364. moeda-loyalty-points...done
# 365. restart-energy-mwat...done
# 366. bloomtoken...done
# 367. omni...done
# 368. radium...done
# 369. mktcoin...done
# 370. spacechain...done
# 371. grid...done
# 372. bitcoin-green...done
# 373. numeraire...done
# 374. selfkey...done
# 375. hive-project...done
# 376. matryx...done
# 377. oax...done
# 378. diamond...done
# 379. blockport...done
# 380. leocoin...done
# 381. carvertical...done
# 382. oraclechain...done
# 383. hi-mutual-society...done
# 384. measurable-data-token...done
# 385. pascal-coin...done
# 386. dadi...done
# 387. aichain...done
# 388. colossusxt...done
# 389. aurora-dao...done
# 390. lykke...done
# 391. vericoin...done
# 392. revolutionvr...done
# 393. paccoin...done
# 394. pareto-network...done
# 395. datawallet...done
# 396. gridcoin...done
# 397. qbao...done
# 398. sureremit...done
# 399. prochain...done
# 400. attention-token-of-media...done
# 401. ormeus-coin...done
# 402. sibcoin...done
# 403. alqo...done
# 404. oneroot-network...done
# 405. flash...done
# 406. divi...done
# 407. storiqa...done
# 408. prizm...done
# 409. solarcoin...done
# 410. te-food...done
# 411. posw-coin...done
# 412. indahash...done
# 413. icos...done
# 414. covesting...done
# 415. latoken...done
# 416. bitclave...done
# 417. florincoin...done
# 418. databits...done
# 419. uquid-coin...done
# 420. guaranteed-ethurance-token-extra...done
# 421. bitcoin-atom...done
# 422. monetaryunit...done
# 423. banyan-network...done
# 424. swarm-fund...done
# 425. credo...done
# 426. e-dinar-coin...done
# 427. blackmoon...done
# 428. mediccoin...done
# 429. axpire...done
# 430. tao...done
# 431. swissborg...done
# 432. devery...done
# 433. hacken...done
# 434. expanse...done
# 435. smartlands...done
# 436. zap...done
# 437. luxcoin...done
# 438. bitusd...done
# 439. polyswarm...done
# 440. aurumcoin...done
# 441. whitecoin...done
# 442. primas...done
# 443. stox...done
# 444. incent...done
# 445. decent-bet...done
# 446. rubycoin...done
# 447. titanium-bar...done
# 448. polybius...done
# 449. clams...done
# 450. bee-token...done
# 451. bismuth...done
# 452. lomocoin...done
# 453. nimiq...done
# 454. ixledger...done
# 455. neoscoin...done
# 456. mooncoin...done
# 457. bitsend...done
# 458. okcash...done
# 459. myriad...done
# 460. encrypgen...done
# 461. patientory...done
# 462. debitum-network...done
# 463. fedoracoin...done
# 464. effect-ai...done
# 465. fintrux-network...done
# 466. rialto...done
# 467. interplanetary-broadcast-coin...done
# 468. neumark...done
# 469. linda...done
# 470. flixxo...done
# 471. remme...done
# 472. cashaa...done
# 473. etheroll...done
# 474. xpa...done
# 475. rise...done
# 476. boolberry...done
# 477. foldingcoin...done
# 478. swarm-city...done
# 479. energycoin...done
# 480. rebl...done
# 481. bitdegree...done
# 482. snovio...done
# 483. nexium...done
# 484. auctus...done
# 485. paragon...done
# 486. everus...done
# 487. block-array...done
# 488. cvcoin...done
# 489. domraider...done
# 490. musicoin...done
# 491. fluz-fluz...done
# 492. payfair...done
# 493. golos...done
# 494. target-coin...done
# 495. quantum...done
# 496. nolimitcoin...done
# 497. dubaicoin-dbix...done
# 498. true-usd...done
# 499. cargox...done
# 500. airtoken...done
# 501. coinpoker...done
# 502. ip-exchange...done
# 503. maecenas...done
# 504. idex-membership...done
# 505. bounty0x...done
# 506. lockchain...done
# 507. bitshares-music...done
# 508. mintcoin...done
# 509. gobyte...done
# 510. newyorkcoin...done
# 511. canyacoin...done
# 512. polis...done
# 513. syndicate...done
# 514. spectrecoin...done
# 515. lala-world...done
# 516. exrnchain...done
# 517. leadcoin...done
# 518. gambit...done
# 519. stealthcoin...done
# 520. pure...done
# 521. insurepal...done
# 522. signal-token...done
# 523. hollywoodcoin...done
# 524. pluton...done
# 525. linker-coin...done
# 526. hat-exchange...done
# 527. waves-community-token...done
# 528. alis...done
# 529. coinfi...done
# 530. mysterium...done
# 531. auroracoin...done
# 532. profile-utility-token...done
# 533. worldcore...done
# 534. toacoin...done
# 535. atn...done
# 536. oxycoin...done
# 537. commerceblock...done
# 538. dynamic...done
# 539. srcoin...done
# 540. investfeed...done
# 541. bitconnect...done
# 542. transfercoin...done
# 543. curecoin...done
# 544. chronobank...done
# 545. napoleonx...done
# 546. ethereum-blue...done
# 547. clearcoin...done
# 548. obits...done
# 549. aventus...done
# 550. solaris...done
# 551. bulwark...done
# 552. bitcrystals...done
# 553. rivetz...done
# 554. pinkcoin...done
# 555. sphere...done
# 556. sequence...done
# 557. playkey...done
# 558. ink-protocol...done
# 559. insights-network...done
# 560. sportyco...done
# 561. circuits-of-value...done
# 562. zilla...done
# 563. elixir...done
# 564. missing adbank
# 565. internet-of-people...done
# 566. fidentiax...done
# 567. atbcoin...done
# 568. eboostcoin...done
# 569. bitqy...done
# 570. xaurum...done
# 571. russian-mining-coin...done
# 572. espers...done
# 573. novacoin...done
# 574. travelflex...done
# 575. tokes...done
# 576. hackspace-capital...done
# 577. eroscoin...done
# 578. mybit-token...done
# 579. breakout-stake...done
# 580. b2bx...done
# 581. bitcoin-plus...done
# 582. korecoin...done
# 583. nework...done
# 584. get-protocol...done
# 585. dether...done
# 586. geocoin...done
# 587. nvo...done
# 588. chainium...done
# 589. heat-ledger...done
# 590. clearpoll...done
# 591. sumokoin...done
# 592. gladius-token...done
# 593. atlant...done
# 594. voisecom...done
# 595. spectre-utility...done
# 596. pandacoin-pnd...done
# 597. artbyte...done
# 598. hoqu...done
# 599. dopecoin...done
# 600. gatcoin...done
# 601. stipend...done
# 602. bunnycoin...done
# 603. dnotes...done
# 604. publica...done
# 605. hellogold...done
# 606. change...done
# 607. bitcoinz...done
# 608. astro...done
# 609. pirl...done
# 610. trueflip...done
# 611. qwark...done
# 612. hexx...done
# 613. life...done
# 614. adhive...done
# 615. cryptoping...done
# 616. leverj...done
# 617. opus...done
# 618. internxt...done
# 619. bitdice...done
# 620. dovu...done
# 621. deviantcoin...done
# 622. spreadcoin...done
# 623. ucash...done
# 624. bitmark...done
# 625. aidcoin...done
# 626. privatix...done
# 627. pesetacoin...done
# 628. ecobit...done
# 629. viuly...done
# 630. chips...done
# 631. memetic...done
# 632. apx...done
# 633. goldcoin...done
# 634. open-trading-network...done
# 635. universal-currency...done
# 636. vice-industry-token...done
# 637. masari...done
# 638. herocoin...done
# 639. europecoin...done
# 640. exclusivecoin...done
# 641. nubits...done
# 642. b3coin...done
# 643. tracto...done
# 644. helbiz...done
# 645. dotcoin...done
# 646. hyperstake...done
# 647. locicoin...done
# 648. cryptopay...done
# 649. bitcloud...done
# 650. dero...done
# 651. quark...done
# 652. daneel...done
# 653. bonpay...done
# 654. syncfab...done
# 655. veriumreserve...done
# 656. gcn-coin...done
# 657. neutron...done
# 658. sharex...done
# 659. education-ecosystem...done
# 660. ethorse...done
# 661. aigang...done
# 662. eztoken...done
# 663. vtorrent...done
# 664. blockcat...done
# 665. 2give...done
# 666. hush...done
# 667. haven-protocol...done
# 668. riecoin...done
# 669. cannabiscoin...done
# 670. sprouts...done
# 671. sether...done
# 672. maxcoin...done
# 673. iungo...done
# 674. copytrack...done
# 675. 1337coin...done
# 676. lampix...done
# 677. experty...done
# 678. dao-casino...done
# 679. global-currency-reserve...done
# 680. piplcoin...done
# 681. adshares...done
# 682. 1world...done
# 683. jet8...done
# 684. starbase...done
# 685. breakout...done
# 686. autonio...done
# 687. goldmint...done
# 688. creditbit...done
# 689. upfiring...done
# 690. 808coin...done
# 691. origami...done
# 692. biocoin...done
# 693. primalbase...done
# 694. denarius-dnr...done
# 695. zephyr...done
# 696. mywish...done
# 697. social-send...done
# 698. bitswift...done
# 699. maverick-chain...done
# 700. xgox...done
# 701. dcorp...done
# 702. blitzcash...done
# 703. audiocoin...done
# 704. altcoin-alt...done
# 705. monacocoin...done
# 706. huntercoin...done
# 707. sharpe-platform-token...done
# 708. vezt...done
# 709. sociall...done
# 710. ixcoin...done
# 711. straks...done
# 712. campuscoin...done
# 713. evergreencoin...done
# 714. karbo...done
# 715. bezop...done
# 716. real...done
# 717. luckchain...done
# 718. buzzcoin...done
# 719. terracoin...done
# 720. startercoin...done
# 721. teslacoin...done
# 722. goodomy...done
# 723. reftoken...done
# 724. trustplus...done
# 725. rupaya...done
# 726. sharechain...done
# 727. zeitcoin...done
# 728. monkey-project...done
# 729. verify...done
# 730. zrcoin...done
# 731. obsidian...done
# 732. pylon-network...done
# 733. uniform-fiscal-object...done
# 734. crave...done
# 735. hirematch...done
# 736. sexcoin...done
# 737. e-gulden...done
# 738. digipulse...done
# 739. vsync-vsx...done
# 740. putincoin...done
# 741. micromoney...done
# 742. trezarcoin...done
# 743. intensecoin...done
# 744. magi...done
# 745. blitzpredict...done
# 746. crycash...done
# 747. ace...done
# 748. interstellar-holdings...done
# 749. zero...done
# 750. rupee...done
# 751. bitzeny...done
# 752. earth-token...done
# 753. linx...done
# 754. sense...done
# 755. chaincoin...done
# 756. jiyo...done
# 757. fantasy-cash...done
# 758. tidex-token...done
# 759. argentum...done
# 760. magnet...done
# 761. darcrus...done
# 762. force...done
# 763. equitrader...done
# 764. eventchain...done
# 765. qvolta...done
# 766. imbrex...done
# 767. capricoin...done
# 768. noblecoin...done
# 769. ethersportz...done
# 770. chronologic...done
# 771. ebtcnew...done
# 772. kekcoin...done
# 773. creativecoin...done
# 774. yocoin...done
# 775. tigereum...done
# 776. speed-mining-service...done
# 777. condensate...done
# 778. ethereum-movie-venture...done
# 779. graft...done
# 780. indorse-token...done
# 781. ignition...done
# 782. litedoge...done
# 783. flypme...done
# 784. innova...done
# 785. latiumx...done
# 786. blocklancer...done
# 787. ellaism...done
# 788. biblepay...done
# 789. wandx...done
# 790. martexcoin...done
# 791. canada-ecoin...done
# 792. unbreakablecoin...done
# 793. inflationcoin...done
# 794. kzcash...done
# 795. ergo...done
# 796. triaconta...done
# 797. digitalprice...done
# 798. inpay...done
# 799. coinlancer...done
# 800. the-cypherfunks...done
# 801. photon...done
# 802. draftcoin...done
# 803. escoro...done
# 804. unitus...done
# 805. sagacoin...done
# 806. deutsche-emark...done
# 807. ganjacoin...done
# 808. bitwhite...done
# 809. oceanlab...done
# 810. ethbits...done
# 811. numus...done
# 812. miners-reward-token...done
# 813. bowhead...done
# 814. neverdie...done
# 815. skincoin...done
# 816. bytecent...done
# 817. jesus-coin...done
# 818. arcticcoin...done
# 819. bitboost...done
# 820. vivo...done
# 821. flik...done
# 822. eltcoin...done
# 823. ongsocial...done
# 824. gpu-coin...done
# 825. incakoin...done
# 826. megacoin...done
# 827. bitsum...done
# 828. legends-room...done
# 829. worldcoin...done
# 830. vulcano...done
# 831. onix...done
# 832. 42-coin...done
# 833. speedcash...done
# 834. mcap...done
# 835. dinastycoin...done
# 836. centra...done
# 837. growers-international...done
# 838. fluttercoin...done
# 839. elementrem...done
# 840. mazacoin...done
# 841. firstcoin...done
# 842. shekel...done
# 843. deuscoin...done
# 844. kolion...done
# 845. global-cryptocurrency...done
# 846. peepcoin...done
# 847. student-coin...done
# 848. skeincoin...done
# 849. equal...done
# 850. adzcoin...done
# 851. procurrency...done
# 852. octoin-coin...done
# 853. moin...done
# 854. galactrum...done
# 855. renos...done
# 856. zetacoin...done
# 857. magiccoin...done
# 858. machinecoin...done
# 859. platinumbar...done
# 860. insanecoin-insn...done
# 861. petrodollar...done
# 862. droxne...done
# 863. britcoin...done
# 864. regalcoin...done
# 865. fujicoin...done
# 866. embers...done
# 867. drp-utility...done
# 868. popularcoin...done
# 869. votecoin...done
# 870. leviarcoin...done
# 871. digitalcoin...done
# 872. ethereumcash...done
# 873. guncoin...done
# 874. bata...done
# 875. ico-openledger...done
# 876. sovereign-hero...done
# 877. bitradio...done
# 878. netko...done
# 879. rimbit...done
# 880. netcoin...done
# 881. authorship...done
# 882. intelligent-trading-foundation...done
# 883. ultracoin...done
# 884. wild-crypto...done
# 885. macron...done
# 886. accelerator-network...done
# 887. bitdeal...done
# 888. startcoin...done
# 889. piggycoin...done
# 890. minereum...done
# 891. bitcoin-scrypt...done
# 892. suretly...done
# 893. crowdcoin...done
# 894. iethereum...done
# 895. whalecoin...done
# 896. bit20...done
# 897. adcoin...done
# 898. op-coin...done
# 899. kushcoin...done
# 900. triangles...done
# 901. qbic...done
# 902. aquariuscoin...done
# 903. bitbtc...done
# 904. bitbar...done
# 905. qubitcoin...done
# 906. swagbucks...done
# 907. guess...done
# 908. cryptocarbon...done
# 909. cream...done
# 910. happycoin...done
# 911. centurion...done
# 912. phoenixcoin...done
# 913. cryptonite...done
# 914. pluscoin...done
# 915. arbitragect...done
# 916. soma...done
# 917. senderon...done
# 918. tittiecoin...done
# 919. sugar-exchange...done
# 920. kurrent...done
# 921. bitgem...done
# 922. litecoin-plus...done
# 923. bitair...done
# 924. bitcoinfast...done
# 925. crystal-clear...done
# 926. veros...done
# 927. nyancoin...done
# 928. roulettetoken...done
# 929. billionaire-token...done
# 930. daxxcoin...done
# 931. mojocoin...done
# 932. garlicoin...done
# 933. aerium...done
# 934. trackr...done
# 935. tokugawa...done
# 936. homeblockcoin...done
# 937. securecoin...done
# 938. atomic-coin...done
# 939. pakcoin...done
# 940. mincoin...done
# 941. network-token...done
# 942. 8bit...done
# 943. cryptojacks...done
# 944. steneum-coin...done
# 945. postcoin...done
# 946. stronghands...done
# 947. tokyo...done
# 948. sterlingcoin...done
# 949. bitgold...done
# 950. tekcoin...done
# 951. goldblocks...done
# 952. cartaxi-token...done
# 953. kubera-coin...done
# 954. cryptoescudo...done
# 955. digital-money-bits...done
# 956. leacoin...done
# 957. cabbage...done
# 958. helleniccoin...done
# 959. zcash-gold...done
# 960. grimcoin...done
# 961. digital-developers-fund...done
# 962. impact...done
# 963. influxcoin...done
# 964. ethereum-gold...done
# 965. c-bit...done
# 966. darsek...done
# 967. octanox...done
# 968. pascal-lite...done
# 969. fujinto...done
# 970. nevacoin...done
# 971. chancoin...done
# 972. neuro...done
# 973. swing...done
# 974. visio...done
# 975. berncash...done
# 976. trident...done
# 977. coin2-1...done
# 978. ethereum-dark...done
# 979. reecoin...done
# 980. globaltoken...done
# 981. desire...done
# 982. phantomx...done
# 983. comet...done
# 984. global-tour-coin...done
# 985. parkbyte...done
# 986. chronos...done
# 987. sixeleven...done
# 988. tajcoin...done
# 989. mustangcoin...done
# 990. vaperscoin...done
# 991. x-coin...done
# 992. high-voltage...done
# 993. biteur...done
# 994. bitcoal...done
# 995. compucoin...done
# 996. litebitcoin...done
# 997. eaglecoin...done
# 998. cachecoin...done
# 999. hicoin...done
# 1000. creatio...done
# 1001. bitasean...done
# 1002. cannation...done
# 1003. eryllium...done
# 1004. goldpieces...done
# 1005. virta-unique-coin...done
# 1006. pioneer-coin...done
# 1007. zozocoin...done
# 1008. newbium...done
# 1009. healthywormcoin...done
# 1010. marijuanacoin...done
# 1011. asiadigicoin...done
# 1012. songcoin...done
# 1013. master-swiscoin...done
# 1014. royal-kingdom-coin...done
# 1015. prcoin...done
# 1016. women...done
# 1017. crevacoin...done
# 1018. coupecoin...done
# 1019. project-x...done
# 1020. concoin...done
# 1021. magnum...done
# 1022. ulatech...done
# 1023. harmonycoin-hmc...done
# 1024. tristar-coin...done
# 1025. faircoin...done
# 1026. the-champcoin...done
# 1027. hedge...done
# 1028. asiacoin...done
# 1029. hubii-network...done
# 1030. kilocoin...done
# 1031. xenon...done
# 1032. tiesdb...done
# 1033. russiacoin...done
# 1034. blockpool...done
# 1035. e-coin...done
# 1036. starta...done
# 1037. bullion...done
# 1038. vslice...done
# 1039. mercury-protocol...done
# 1040. carboncoin...done
# 1041. farad...done
# 1042. encryptotel...done
# 1043. tokenbox...done
# 1044. masternodecoin...done
# 1045. flappycoin...done
# 1046. leafcoin...done
# 1047. kobocoin...done
# 1048. bluecoin...done
# 1049. fundyourselfnow...done
# 1050. anoncoin...done
# 1051. orbitcoin...done
# 1052. smileycoin...done
# 1053. universe...done
# 1054. dfscoin...done
# 1055. woodcoin...done
# 1056. unicoin...done
# 1057. shorty...done
# 1058. version...done
# 1059. i0coin...done
# 1060. zennies...done
# 1061. hitcoin...done
# 1062. fucktoken...done
# 1063. starcredits...done
# 1064. bittokens...done
# 1065. emphy...done
# 1066. etheriya...done
# 1067. fantomcoin...done
# 1068. metalcoin...done
# 1069. bitpark-coin...done
# 1070. unify...done
# 1071. hobonickels...done
# 1072. opal...done
# 1073. nushares...done
# 1074. monster-byte...done
# 1075. commodity-ad-network...done
# 1076. blockpay...done
# 1077. bigup...done
# 1078. ethbet...done
# 1079. jetcoin...done
# 1080. trollcoin...done
# 1081. shadowcash...done
# 1082. iticoin...done
# 1083. fastcoin...done
# 1084. lanacoin...done
# 1085. tagcoin...done
# 1086. bitstar...done
# 1087. hodlcoin...done
# 1088. ebitcoin-cash...done
# 1089. blazecoin...done
# 1090. mao-zedong...done
# 1091. btctalkcoin...done
# 1092. trumpcoin...done
# 1093. aricoin...done
# 1094. gaia...done
# 1095. paycoin2...done
# 1096. halcyon...done
# 1097. synergy...done
# 1098. virtacoin...done
# 1099. copico...done
# 1100. dashcoin...done
# 1101. purevidz...done
# 1102. smartcoin...done
# 1103. bitsilver...done
# 1104. titcoin...done
# 1105. joulecoin...done
# 1106. truckcoin...done
# 1107. wavesgo...done
# 1108. coinonatx...done
# 1109. scorecoin...done
# 1110. supercoin...done
# 1111. dix-asset...done
# 1112. manna...done
# 1113. missing motocoin
# 1114. flycoin...done
# 1115. global-jobcoin...done
# 1116. cypher...done
# 1117. irishcoin...done
# 1118. bitcoin-red...done
# 1119. parallelcoin...done
# 1120. granitecoin...done
# 1121. tigercoin...done
# 1122. ultimate-secure-cash...done
# 1123. philosopher-stones...done
# 1124. ambercoin...done
# 1125. prototanium...done
# 1126. elcoin-el...done
# 1127. cashcoin...done
# 1128. islacoin...done
# 1129. evil-coin...done
# 1130. blakecoin...done
# 1131. chesscoin...done
# 1132. bolivarcoin...done
# 1133. bitz...done
# 1134. gapcoin...done
# 1135. ronpaulcoin...done
# 1136. erc20...done
# 1137. mineum...done
# 1138. cannacoin...done
# 1139. coin...done
# 1140. icoin...done
# 1141. tattoocoin...done
# 1142. sproutsextreme...done
# 1143. freicoin...done
# 1144. ratecoin...done
# 1145. ammo-reloaded...done
# 1146. gameunits...done
# 1147. emerald...done
# 1148. 300-token...done
# 1149. bitcurrency...done
# 1150. datacoin...done
# 1151. shadow-token...done
# 1152. marscoin...done
# 1153. globalboost-y...done
# 1154. golfcoin...done
# 1155. signatum...done
# 1156. eternity...done
# 1157. polcoin...done
# 1158. digicube...done
# 1159. litebar...done
# 1160. revolvercoin...done
# 1161. paycon...done
# 1162. ecocoin...done
# 1163. spacecoin...done
# 1164. abjcoin...done
# 1165. quebecoin...done
# 1166. octocoin...done
# 1167. jin-coin...done
# 1168. redcoin...done
# 1169. px...done
# 1170. nekonium...done
# 1171. catcoin...done
# 1172. satoshimadness...done
# 1173. zurcoin...done
# 1174. quatloo...done
# 1175. theresa-may-coin...done
# 1176. amsterdamcoin...done
# 1177. elacoin...done
# 1178. rubies...done
# 1179. virtualcoin...done
# 1180. prime-xi...done
# 1181. globalcoin...done
# 1182. bankcoin...done
# 1183. xios...done
# 1184. sativacoin...done
# 1185. boostcoin...done
# 1186. crypto...done
# 1187. solarflarecoin...done
# 1188. independent-money-system...done
# 1189. yacoin...done
# 1190. briacoin...done
# 1191. secretcoin...done
# 1192. icobid...done
# 1193. honey...done
# 1194. virtacoinplus...done
# 1195. fincoin...done
# 1196. evotion...done
# 1197. bumbacoin...done
# 1198. firecoin...done
# 1199. bitquark...done
# 1200. ccore...done
# 1201. sooncoin...done
# 1202. fuzzballs...done
# 1203. starcash-network...done
# 1204. brat...done
# 1205. hempcoin-hmp...done
# 1206. dalecoin...done
# 1207. blackstar...done
# 1208. guccionecoin...done
# 1209. enigma...done
# 1210. joincoin...done
# 1211. acoin...done
# 1212. soilcoin...done
# 1213. dollarcoin...done
# 1214. bitcoin-planet...done
# 1215. bitcoin-21...done
# 1216. flaxscript...done
# 1217. yenten...done
# 1218. beatcoin...done
# 1219. eurocoin...done
# 1220. glasscoin...done
# 1221. money...done
# 1222. funcoin...done
# 1223. coinonat...done
# 1224. billarycoin...done
# 1225. digital-rupees...done
# 1226. roofs...done
# 1227. benjirolls...done
# 1228. vip-tokens...done
# 1229. advanced-internet-blocks...done
# 1230. gold-pressed-latinum...done
# 1231. californium...done
# 1232. allsafe...done
# 1233. allion...done
# 1234. debitcoin...done
# 1235. agrolifecoin...done
# 1236. bipcoin...done
# 1237. ride-my-car...done
# 1238. useless-ethereum-token...done
# 1239. bolenum...done
# 1240. kronecoin...done
# 1241. madcoin...done
# 1242. javascript-token...done
# 1243. metal-music-coin...done
# 1244. quazarcoin...done
# 1245. uro...done
# 1246. bnrtxcoin...done
# 1247. shilling...done
# 1248. warp...done
# 1249. postoken...done
# 1250. jewels...done
# 1251. bitcedi...done
# 1252. printerium...done
# 1253. zetamicron...done
# 1254. slevin...done
# 1255. pulse...done
# 1256. artex-coin...done
# 1257. iconic...done
# 1258. exchangen...done
# 1259. interzone...done
# 1260. ponzicoin...done
# 1261. dappster...done
# 1262. veltor...done
# 1263. geertcoin...done
# 1264. zayedcoin...done
# 1265. playercoin...done
# 1266. bios-crypto...done
# 1267. mindcoin...done
# 1268. litecoin-ultra...done
# 1269. steps...done
# 1270. ripto-bux...done
# 1271. arbit...done
# 1272. rsgpcoin...done
# 1273. cryptoworldx-token...done
# 1274. piecoin...done
# 1275. letitride...done
# 1276. doubloon...done
# 1277. dreamcoin...done
# 1278. luna-coin...done
# 1279. tagrcoin...done
# 1280. cthulhu-offerings...done
# 1281. kingn-coin...done
# 1282. bowscoin...done
# 1283. milocoin...done
# 1284. litecred...done
# 1285. torcoin-tor...done
# 1286. vector...done
# 1287. destiny...done
# 1288. zonecoin...done
# 1289. impulsecoin...done
# 1290. gbcgoldcoin...done
# 1291. wild-beast-block...done
# 1292. osmiumcoin...done
# 1293. bitvolt...done
# 1294. credence-coin...done
# 1295. dollar-online...done
# 1296. sydpak...done
# 1297. posex...done
# 1298. plncoin...done
# 1299. anarchistsprime...done
# 1300. argus...done
# 1301. save-and-gain...done
# 1302. coimatic-3...done
# 1303. jobscoin...done
# 1304. rawcoin2...done
# 1305. p7coin...done
# 1306. biobar...done
# 1307. elysium...done
# 1308. ibank...done
# 1309. socialcoin-socc...done
# 1310. selfiecoin...done
# 1311. nodecoin...done
# 1312. geysercoin...done
# 1313. coimatic-2...done
# 1314. vault-coin...done
# 1315. levoplus...done
# 1316. digital-credits...done
# 1317. pizzacoin...done
# 1318. caliphcoin...done
# 1319. futurexe...done
# 1320. ebittree-coin...done
# 1321. poly-ai...done
# 1322. ckusd...done
# 1323. penta...done
# 1324. topchain...done
# 1325. iquant...done
# 1326. holo...done
# 1327. chatcoin...done
# 1328. kcash...done
# 1329. starchain...done
# 1330. noah-coin...done
# 1331. content-and-ad-network...done
# 1332. monero-classic...done
# 1333. coinmeet...done
# 1334. zebi...done
# 1335. nexo...done
# 1336. dragon-coins...done
# 1337. molecular-future...done
# 1338. eosdac...done
# 1339. acute-angle-cloud...done
# 1340. atmcoin...done
# 1341. oceanchain...done
# 1342. dignity...done
# 1343. show...done
# 1344. realchain...done
# 1345. bitstation...done
# 1346. fargocoin...done
# 1347. aware...done
# 1348. bitcoinx...done
# 1349. lightning-bitcoin...done
# 1350. mark-space...done
# 1351. moac...done
# 1352. ipchain...done
# 1353. super-bitcoin...done
# 1354. filecoin...done
# 1355. bnktothefuture...done
# 1356. gems-protocol...done
# 1357. neurotoken...done
# 1358. selfsell...done
# 1359. ofcoin...done
# 1360. exchange-union...done
# 1361. electronic-pk-chain...done
# 1362. maggie...done
# 1363. stockchain...done
# 1364. united-bitcoin...done
# 1365. monero-original...done
# 1366. starcointv...done
# 1367. halalchain...done
# 1368. vipstar-coin...done
# 1369. fidelium...done
# 1370. rublix...done
# 1371. lightchain...done
# 1372. proxeus...done
# 1373. read...done
# 1374. lendingblock...done
# 1375. tezos...done
# 1376. win-coin...done
# 1377. aidos-kuneen...done
# 1378. infinity-economics...done
# 1379. pressone...done
# 1380. blockcdn...done
# 1381. valuechain...done
# 1382. comsa-eth...done
# 1383. bastonet...done
# 1384. pixie-coin...done
# 1385. cfun...done
# 1386. weth...done
# 1387. aditus...done
# 1388. qube...done
# 1389. curriculum-vitae...done
# 1390. fairgame...done
# 1391. trakinvest...done
# 1392. comsa-xem...done
# 1393. b2bcoin...done
# 1394. etherecash...done
# 1395. arbitracoin...done
# 1396. bitcoin-god...done
# 1397. peculium...done
# 1398. cropcoin...done
# 1399. decentralized-machine-learning...done
# 1400. ox-fina...done
# 1401. jingtum-tech...done
# 1402. sphre-air...done
# 1403. tokendesk...done
# 1404. animation-vision-cash...done
# 1405. belugapay...done
# 1406. bigone-token...done
# 1407. strikebitclub...done
# 1408. brahmaos...done
# 1409. wawllet...done
# 1410. budbo...done
# 1411. aphelion...done
# 1412. animecoin...done
# 1413. snipcoin...done
# 1414. greenmed...done
# 1415. hyper-pay...done
# 1416. stellite...done
# 1417. phi-token...done
# 1418. segwit2x...done
# 1419. consensus...done
# 1420. infinitecoin...done
# 1421. internet-of-things...done
# 1422. unlimitedip...done
# 1423. investdigital...done
# 1424. ea-coin...done
# 1425. safe-trade-coin...done
# 1426. belacoin...done
# 1427. missing techshares
# 1428. alphabitcoinfund...done
# 1429. swisscoin...done
# 1430. msd...done
# 1431. marxcoin...done
# 1432. golos-gold...done
# 1433. lendroid-support-token...done
# 1434. friends...done
# 1435. candy...done
# 1436. blakestar...done
# 1437. embercoin...done
# 1438. w3coin...done
# 1439. amlt...done
# 1440. cryptopiafeeshares...done
# 1441. acchain...done
# 1442. betacoin...done
# 1443. uttoken...done
# 1444. clubcoin...done
# 1445. slothcoin...done
# 1446. atmos...done
# 1447. entcash...done
# 1448. president-johnson...done
# 1449. gamechain...done
# 1450. president-trump...done
# 1451. teslacoilcoin...done
# 1452. aces...done
# 1453. first-bitcoin-capital...done
# 1454. etherdelta-token...done
# 1455. wa-space...done
# 1456. macro1...done
# 1457. runners...done
# 1458. klondikecoin...done
# 1459. rabbitcoin...done
# 1460. titanium-blockchain...done
# 1461. edrcoin...done
# 1462. pabyosi-coin-special...done
# 1463. royalties...done
# 1464. sparks...done
# 1465. hodl-bucks...done
# 1466. anryze...done
# 1467. biotron...done
# 1468. numuscash...done
# 1469. corion...done
# 1470. zilbercoin...done
# 1471. minex...done
# 1472. namocoin...done
# 1473. sjwcoin...done
# 1474. india-coin...done
# 1475. superior-coin...done
# 1476. harvest-masternode-coin...done
# 1477. sigmacoin...done
# 1478. plexcoin...done
# 1479. davorcoin...done
# 1480. gold-reward-token...done
# 1481. bubble...done
# 1482. terranova...done
# 1483. alpacoin...done
# 1484. dutch-coin...done
# 1485. indicoin...done
# 1486. royalcoin...done
# 1487. francs...done
# 1488. bt2-cst...done
# 1489. dynamiccoin...done
# 1490. digital-bullion-gold...done
# 1491. wi-coin...done
# 1492. tattoocoin-limited...done
# 1493. bestchain...done
# 1494. sakuracoin...done
# 1495. ereal...done
# 1496. zengold...done
# 1497. tellurion...done
# 1498. avatarcoin...done
# 1499. universalroyalcoin...done
# 1500. landcoin...done
# 1501. btcmoon...done
# 1502. huncoin...done
# 1503. wink...done
# 1504. protean...done
# 1505. altcommunity-coin...done
# 1506. cubits...done
# 1507. grandcoin...done
# 1508. nitro...done
# 1509. zsecoin...done
# 1510. cyder...done
# 1511. storjcoin-x...done
# 1512. cloud...done
# 1513. operand...done
# 1514. fapcoin...done
# 1515. bitbase...done
# 1516. supernet-unity...done
# 1517. primulon...done
# 1518. topaz...done
# 1519. bitserial...done
# 1520. omicron...done
# 1521. encryptotel-eth...done
# 1522. stex...done
# 1523. blazercoin...done
# 1524. donationcoin...done
# 1525. rcoin...done
# 1526. akuya-coin...done
# 1527. neo-gold...done
# 1528. fonziecoin...done
# 1529. batcoin...done
# 1530. antimatter...done
# 1531. wearesatoshi...done
# 1532. smoke...done
# 1533. levocoin...done
# 1534. magnetcoin...done
# 1535. aseancoin...done
# 1536. xtd-coin...done
# 1537. coffeecoin...done
# 1538. uncoin...done
# 1539. turbocoin...done
# 1540. first-bitcoin...done
# 1541. shacoin...done
# 1542. rublebit...done
# 1543. birds...done
# 1544. cryptcoin...done
# 1545. qora...done
# 1546. sisa...done
# 1547. ethereum-lite...done
# 1548. goldmaxcoin...done
# 1549. musiconomi...done
# 1550. halloween-coin...done
# 1551. lepen...done
# 1552. ur...done
# 1553. todaycoin...done
# 1554. trickycoin...done
# 1555. mobilecash...done
# 1556. axiom...done
# 1557. t-coin...done
# 1558. quotient...done
# 1559. avoncoin...done
# 1560. high-gain...done
# 1561. bitok...done
# 1562. frankywillcoin...done
# 1563. cybercoin...done
# 1564. topcoin...done
# 1565. gaycoin...done
# 1566. thecreed...done
# 1567. cycling-coin...done
# 1568. prismchain...done
# 1569. dashs...done
# 1570. futcoin...done
# 1571. karmacoin...done
# 1572. netbit...done
# 1573. pirate-blocks...done
# 1574. hyper...done
# 1575. deltacredits...done
# 1576. eggcoin...done
# 1577. gameleaguecoin...done
# 1578. sharkcoin...done
# 1579. shellcoin...done
# 1580. moneta2...done
# 1581. cashme...done
# 1582. x2...done
# 1583. opescoin...done
# 1584. psilocybin...done
# 1585. paypeer...done
# 1586. darklisk...done
# 1587. richcoin...done
# 1588. happy-creator-coin...done
# 1589. linkedcoin...done
# 1590. international-diamond...done
# 1591. pokecoin...done
# 1592. ugain...done
# 1593. sportscoin...done
# 1594. lazaruscoin...done
# 1595. regacoin...done
# 1596. kashhcoin...done
# 1597. rhfcoin...done
# 1598. fazzcoin...done
# 1599. cheapcoin...done
# 1600. vcash...done
# 1601. bitsoar...done
# 1602. missing farstcoin

# %%
##Step 2 of 2, load data into MySQL

##%%time
#define datatypes from scrape
dtypes = {'coin_name':sqlalchemy.types.NVARCHAR(length=100),'date_hist':sqlalchemy.types.Date,'open_price':sqlalchemy.types.Float(asdecimal=True),'close_price':sqlalchemy.types.Float(asdecimal=True),
          'high_price':sqlalchemy.types.Float(asdecimal=True),'low_price':sqlalchemy.types.Float(asdecimal=True),'market_cap':sqlalchemy.types.BIGINT,'volume':sqlalchemy.types.BIGINT}

# Load data to MySQL
final_coin_data.to_sql(name='historical_crypto', con=engine, if_exists = 'replace', index=False, chunksize=10000 , dtype=dtypes)

# %%
### Generate volatility metrics and create new analytics table in MySQL
## FYI, I dont think this calculation is correct. I am getting a lot of nulls

analysis_historical =final_coin_data[['coin_name','date_hist','open_price','close_price']]

analysis_historical['Volitility_30_day'] = analysis_historical.groupby('coin_name')['close_price'].rolling(window=30).std().reset_index(drop=True)
analysis_historical['Volitility_90_day'] = analysis_historical.groupby('coin_name')['close_price'].rolling(window=90).std().reset_index(drop=True)
analysis_historical['Volitility_365_day'] = analysis_historical.groupby('coin_name')['close_price'].rolling(window=365).std().reset_index(drop=True) 

## fyi, normally annual volitility is 255 instead of 365 since there are only 255 trading days in a year, but since crypto is all 365 then I leave at 365

## Push to MySQL
analysis_historical.to_sql(name='analysis_historical', con=engine, if_exists = 'replace', index=False, chunksize=10000)
